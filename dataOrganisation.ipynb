# %%
import pandas as pd
import json

# Load Excel sheets
try:
    data = pd.read_excel("data.xlsx")

     # data =  data.drop(columns ='activityType_2')
    def parse_or_empty(value):
        if pd.isna(value) or value == '':
            return None
        try:
            # json.loads expects double quotes for keys/strings.
            # We can replace single quotes with double quotes.
            # However, for robustness, 'ast.literal_eval' is often safer for Python-like strings.
            import ast
            return ast.literal_eval(value)
        except (ValueError, SyntaxError):
            # If parsing fails, return an empty list or handle as an error
            return None
    
    data['month_year_repeat_group'] = data['month_year_repeat_group'].apply(parse_or_empty)
    data['assessors'] = data['assessors'].apply(parse_or_empty)

except FileNotFoundError:
    print("Error: 'data.xlsx' not found. Please make sure the Excel file is in the same directory as the script.")
    exit()

# Convert DataFrame to a list of dictionaries
# Each dictionary represents a row in the DataFrame
json_data = data.to_dict(orient='records')

# Save to JSON
output_file = "data.json"



try:
    with open(output_file, "w") as file:
        json.dump(json_data, file, indent=4)
    print(f"Data successfully saved to {output_file}")


except IOError:
    print(f"Error: Could not write to file {output_file}. Check file permissions or disk space.")
    exit()





# Print the JSON
print("\n--- JSON Output ---")
print(json.dumps(json_data, indent=4))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
data
# Out:
#      Unnamed: 0 startingMonth  startingYear endingMonth  endingYear  \
# 0             0           NaN           NaN         NaN         NaN
# 1             1           NaN           NaN         NaN         NaN
# 2             2         April        2025.0        June      2025.0
# 3             3           NaN           NaN         NaN         NaN
# 4             4         April        2025.0        June      2025.0
# ..          ...           ...           ...         ...         ...
# 138         138           NaN           NaN         NaN         NaN
# 139         139           NaN           NaN         NaN         NaN
# 140         140           NaN           NaN         NaN         NaN
# 141         141           NaN           NaN         NaN         NaN
# 142         142       October        2024.0         May      2025.0
#
#     clientSpaceSize spaceCleaniness waitingSpace examinationroomTemperature  \
# 0               NaN             NaN          NaN                        NaN
# 1               NaN             NaN          NaN                        NaN
# 2               NaN             NaN          NaN                        NaN
# 3               NaN             NaN          NaN                        NaN
# 4               NaN             NaN          NaN                        NaN
# ..              ...             ...          ...                        ...
# 138             NaN             NaN          NaN                        NaN
# 139             NaN             NaN          NaN                        NaN
# 140             NaN             NaN          NaN                        NaN
# 141             NaN             NaN          NaN                        NaN
# 142             NaN             NaN          NaN                        NaN
#
#     examionationroomLighting  ...  \
# 0                        NaN  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                        NaN  ...
# ..                       ...  ...
# 138                      NaN  ...
# 139                      NaN  ...
# 140                      NaN  ...
# 141                      NaN  ...
# 142                      NaN  ...
#
#     comments_and_recommendations_data_triangulation       today  \
# 0                                               NaN  24/07/2025
# 1                                               NaN  24/07/2025
# 2                     Data is tallying in all areas  24/07/2025
# 3                                               NaN  24/07/2025
# 4                                  Data is tallying  24/07/2025
# ..                                              ...         ...
# 138                                             NaN         NaN
# 139                                             NaN         NaN
# 140                                             NaN         NaN
# 141                                             NaN         NaN
# 142                                             NaN         NaN
#
#     designation__job_title full_name organisation section   District  \
# 0                      NaN       NaN          NaN       a     MATOBO
# 1                      NaN       NaN          NaN       b     MATOBO
# 2                      NaN       NaN          NaN       c     MATOBO
# 3                      NaN       NaN          NaN       b     MATOBO
# 4                      NaN       NaN          NaN       c     MATOBO
# ..                     ...       ...          ...     ...        ...
# 138                    NaN       NaN          NaN       d    SANYATI
# 139                    NaN       NaN          NaN       c  MARONDERA
# 140                    NaN       NaN          NaN       d  MARONDERA
# 141                    NaN       NaN          NaN       e  MARONDERA
# 142                    NaN       NaN          NaN       b  MARONDERA
#
#        facility                            month_year_repeat_group  \
# 0         Bazha                                               None
# 1         Bazha                                               None
# 2         Bazha  [{'calculatedMonth': 'April', 'calculatedYear'...
# 3       Fumugwe                                               None
# 4       Fumugwe  [{'calculatedMonth': 'April', 'calculatedYear'...
# ..          ...                                                ...
# 138      Rimuka                                               None
# 139  Dombotombo                                               None
# 140  Dombotombo                                               None
# 141  Dombotombo                                               None
# 142  Dombotombo  [{'calculatedMonth': 'October', 'calculatedYea...
#
#         username
# 0      nmunikira
# 1      nmunikira
# 2      nmunikira
# 3      nmunikira
# 4      nmunikira
# ..           ...
# 138      fgwenzi
# 139  tmunyaradzi
# 140     jgavhera
# 141     jgavhera
# 142     amutenha
#
# [143 rows x 627 columns]
