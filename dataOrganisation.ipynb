# %%
import pandas as pd
import json

# Load Excel sheets
try:
    data = pd.read_excel("data.xlsx")

     # data =  data.drop(columns ='activityType_2')
    def parse_or_empty(value):
        if pd.isna(value) or value == '':
            return None
        try:
            # json.loads expects double quotes for keys/strings.
            # We can replace single quotes with double quotes.
            # However, for robustness, 'ast.literal_eval' is often safer for Python-like strings.
            import ast
            return ast.literal_eval(value)
        except (ValueError, SyntaxError):
            # If parsing fails, return an empty list or handle as an error
            return None
    
    data['month_year_repeat_group'] = data['month_year_repeat_group'].apply(parse_or_empty)
    data['assessors'] = data['assessors'].apply(parse_or_empty)

except FileNotFoundError:
    print("Error: 'data.xlsx' not found. Please make sure the Excel file is in the same directory as the script.")
    exit()

# Convert DataFrame to a list of dictionaries
# Each dictionary represents a row in the DataFrame
json_data = data.to_dict(orient='records')

# Save to JSON
output_file = "data.json"



try:
    with open(output_file, "w") as file:
        json.dump(json_data, file, indent=4)
    print(f"Data successfully saved to {output_file}")


except IOError:
    print(f"Error: Could not write to file {output_file}. Check file permissions or disk space.")
    exit()





# Print the JSON
print("\n--- JSON Output ---")
print(json.dumps(json_data, indent=4))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
data
# Out:
#      Unnamed: 0 startingMonth  startingYear endingMonth  endingYear  \
# 0             0           NaN           NaN         NaN         NaN
# 1             1           NaN           NaN         NaN         NaN
# 2             2         April        2025.0        June      2025.0
# 3             3           NaN           NaN         NaN         NaN
# 4             4           NaN           NaN         NaN         NaN
# ..          ...           ...           ...         ...         ...
# 109         109           NaN           NaN         NaN         NaN
# 110         110           NaN           NaN         NaN         NaN
# 111         111           NaN           NaN         NaN         NaN
# 112         112           NaN           NaN         NaN         NaN
# 113         113       October        2024.0         May      2025.0
#
#     clientSpaceSize spaceCleaniness waitingSpace examinationroomTemperature  \
# 0               NaN             NaN          NaN                        NaN
# 1               NaN             NaN          NaN                        NaN
# 2               NaN             NaN          NaN                        NaN
# 3               NaN             NaN          NaN                        NaN
# 4               NaN             NaN          NaN                        NaN
# ..              ...             ...          ...                        ...
# 109             NaN             NaN          NaN                        NaN
# 110             NaN             NaN          NaN                        NaN
# 111             NaN             NaN          NaN                        NaN
# 112             NaN             NaN          NaN                        NaN
# 113             NaN             NaN          NaN                        NaN
#
#     examionationroomLighting  ...  \
# 0                        NaN  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                        NaN  ...
# ..                       ...  ...
# 109                      NaN  ...
# 110                      NaN  ...
# 111                      NaN  ...
# 112                      NaN  ...
# 113                      NaN  ...
#
#     comments_and_recommendations_data_triangulation today  \
# 0                                               NaN   NaN
# 1                                               NaN   NaN
# 2                                               NaN   NaN
# 3                                               NaN   NaN
# 4                                               NaN   NaN
# ..                                              ...   ...
# 109                                             NaN   NaN
# 110                                             NaN   NaN
# 111                                             NaN   NaN
# 112                                             NaN   NaN
# 113                                             NaN   NaN
#
#     designation__job_title full_name organisation section   District  \
# 0                      NaN       NaN          NaN       b     LUPANE
# 1                      NaN       NaN          NaN       a     LUPANE
# 2                      NaN       NaN          NaN       c     LUPANE
# 3                      NaN       NaN          NaN       a     LUPANE
# 4                      NaN       NaN          NaN       b     LUPANE
# ..                     ...       ...          ...     ...        ...
# 109                    NaN       NaN          NaN       d    SANYATI
# 110                    NaN       NaN          NaN       c  MARONDERA
# 111                    NaN       NaN          NaN       d  MARONDERA
# 112                    NaN       NaN          NaN       e  MARONDERA
# 113                    NaN       NaN          NaN       b  MARONDERA
#
#                            facility  \
# 0    Kanyandavu Rural Health Centre
# 1    Kanyandavu Rural Health Centre
# 2    Kanyandavu Rural Health Centre
# 3      Dandanda Rural Health Centre
# 4      Dandanda Rural Health Centre
# ..                              ...
# 109                          Rimuka
# 110                      Dombotombo
# 111                      Dombotombo
# 112                      Dombotombo
# 113                      Dombotombo
#
#                                month_year_repeat_group     username
# 0                                                 None     jgavhera
# 1                                                 None     jgavhera
# 2    [{'calculatedMonth': 'April', 'calculatedYear'...     jgavhera
# 3                                                 None     jgavhera
# 4                                                 None     jgavhera
# ..                                                 ...          ...
# 109                                               None      fgwenzi
# 110                                               None  tmunyaradzi
# 111                                               None     jgavhera
# 112                                               None     jgavhera
# 113  [{'calculatedMonth': 'October', 'calculatedYea...     amutenha
#
# [114 rows x 627 columns]
