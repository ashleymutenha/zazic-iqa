# %%
import pandas as pd
import json

# Load Excel sheets
try:
    data = pd.read_excel("data.xlsx")

     # data =  data.drop(columns ='activityType_2')
    def parse_or_empty(value):
        if pd.isna(value) or value == '':
            return None
        try:
            # json.loads expects double quotes for keys/strings.
            # We can replace single quotes with double quotes.
            # However, for robustness, 'ast.literal_eval' is often safer for Python-like strings.
            import ast
            return ast.literal_eval(value)
        except (ValueError, SyntaxError):
            # If parsing fails, return an empty list or handle as an error
            return None
    
    data['month_year_repeat_group'] = data['month_year_repeat_group'].apply(parse_or_empty)
    data['assessors'] = data['assessors'].apply(parse_or_empty)

except FileNotFoundError:
    print("Error: 'data.xlsx' not found. Please make sure the Excel file is in the same directory as the script.")
    exit()

# Convert DataFrame to a list of dictionaries
# Each dictionary represents a row in the DataFrame
json_data = data.to_dict(orient='records')

# Save to JSON
output_file = "data.json"



try:
    with open(output_file, "w") as file:
        json.dump(json_data, file, indent=4)
    print(f"Data successfully saved to {output_file}")


except IOError:
    print(f"Error: Could not write to file {output_file}. Check file permissions or disk space.")
    exit()





# Print the JSON
print("\n--- JSON Output ---")
print(json.dumps(json_data, indent=4))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
data
# Out:
#      Unnamed: 0 startingMonth  startingYear endingMonth  endingYear  \
# 0             0           NaN           NaN         NaN         NaN
# 1             1           NaN           NaN         NaN         NaN
# 2             2          July        2025.0   September      2025.0
# 3             3         April        2025.0        June      2025.0
# 4             4           NaN           NaN         NaN         NaN
# ..          ...           ...           ...         ...         ...
# 162         162           NaN           NaN         NaN         NaN
# 163         163           NaN           NaN         NaN         NaN
# 164         164           NaN           NaN         NaN         NaN
# 165         165           NaN           NaN         NaN         NaN
# 166         166       October        2024.0         May      2025.0
#
#     clientSpaceSize spaceCleaniness waitingSpace examinationroomTemperature  \
# 0               NaN             NaN          NaN                        NaN
# 1               NaN             NaN          NaN                        NaN
# 2               NaN             NaN          NaN                        NaN
# 3               NaN             NaN          NaN                        NaN
# 4               NaN             NaN          NaN                        NaN
# ..              ...             ...          ...                        ...
# 162             NaN             NaN          NaN                        NaN
# 163             NaN             NaN          NaN                        NaN
# 164             NaN             NaN          NaN                        NaN
# 165             NaN             NaN          NaN                        NaN
# 166             NaN             NaN          NaN                        NaN
#
#     examionationroomLighting  ...  \
# 0                        NaN  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                        NaN  ...
# ..                       ...  ...
# 162                      NaN  ...
# 163                      NaN  ...
# 164                      NaN  ...
# 165                      NaN  ...
# 166                      NaN  ...
#
#        comments_and_recommendations_data_triangulation       today  \
# 0                                                  NaN  27/08/2025
# 1                                                  NaN  27/08/2025
# 2                                    nil mcs in August  27/08/2025
# 3    There is need scale up demand creation in the ...  24/07/2025
# 4                                                  NaN  24/07/2025
# ..                                                 ...         ...
# 162                                                NaN         NaN
# 163                                                NaN         NaN
# 164                                                NaN         NaN
# 165                                                NaN         NaN
# 166                                                NaN         NaN
#
#     designation__job_title          full_name organisation section   District  \
# 0                      NaN                NaN          NaN       a     MATOBO
# 1                      NaN                NaN          NaN       b     MATOBO
# 2                      NaN                NaN          NaN       c     MATOBO
# 3                      M&E  pesanai chatikobo      ZICHIRE       c     MATOBO
# 4                      NaN                NaN          NaN       a     MATOBO
# ..                     ...                ...          ...     ...        ...
# 162                    NaN                NaN          NaN       d    SANYATI
# 163                    NaN                NaN          NaN       c  MARONDERA
# 164                    NaN                NaN          NaN       d  MARONDERA
# 165                    NaN                NaN          NaN       e  MARONDERA
# 166                    NaN                NaN          NaN       b  MARONDERA
#
#                        facility  \
# 0    St Joseph's Rural Hospital
# 1    St Joseph's Rural Hospital
# 2    St Joseph's Rural Hospital
# 3                         Bazha
# 4                       Fumugwe
# ..                          ...
# 162                      Rimuka
# 163                  Dombotombo
# 164                  Dombotombo
# 165                  Dombotombo
# 166                  Dombotombo
#
#                                month_year_repeat_group     username
# 0                                                 None      fgwenzi
# 1                                                 None      fgwenzi
# 2    [{'calculatedMonth': 'July', 'calculatedYear':...      fgwenzi
# 3    [{'calculatedMonth': 'April', 'calculatedYear'...        percy
# 4                                                 None        percy
# ..                                                 ...          ...
# 162                                               None      fgwenzi
# 163                                               None  tmunyaradzi
# 164                                               None     jgavhera
# 165                                               None     jgavhera
# 166  [{'calculatedMonth': 'October', 'calculatedYea...     amutenha
#
# [167 rows x 627 columns]
