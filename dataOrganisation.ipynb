# %%
import pandas as pd
import json

# Load Excel sheets
try:
    data = pd.read_excel("data.xlsx")

     # data =  data.drop(columns ='activityType_2')
    def parse_or_empty(value):
        if pd.isna(value) or value == '':
            return None
        try:
            # json.loads expects double quotes for keys/strings.
            # We can replace single quotes with double quotes.
            # However, for robustness, 'ast.literal_eval' is often safer for Python-like strings.
            import ast
            return ast.literal_eval(value)
        except (ValueError, SyntaxError):
            # If parsing fails, return an empty list or handle as an error
            return None
    
    data['month_year_repeat_group'] = data['month_year_repeat_group'].apply(parse_or_empty)
    data['assessors'] = data['assessors'].apply(parse_or_empty)

except FileNotFoundError:
    print("Error: 'data.xlsx' not found. Please make sure the Excel file is in the same directory as the script.")
    exit()

# Convert DataFrame to a list of dictionaries
# Each dictionary represents a row in the DataFrame
json_data = data.to_dict(orient='records')

# Save to JSON
output_file = "data.json"



try:
    with open(output_file, "w") as file:
        json.dump(json_data, file, indent=4)
    print(f"Data successfully saved to {output_file}")


except IOError:
    print(f"Error: Could not write to file {output_file}. Check file permissions or disk space.")
    exit()





# Print the JSON
print("\n--- JSON Output ---")
print(json.dumps(json_data, indent=4))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
data
# Out:
#      Unnamed: 0 startingMonth  startingYear endingMonth  endingYear  \
# 0             0         April        2025.0      August      2025.0
# 1             1         April        2025.0      August      2025.0
# 2             2         April        2025.0      August      2025.0
# 3             3         April        2025.0      August      2025.0
# 4             4        August        2025.0      August      2025.0
# ..          ...           ...           ...         ...         ...
# 238         238           NaN           NaN         NaN         NaN
# 239         239           NaN           NaN         NaN         NaN
# 240         240           NaN           NaN         NaN         NaN
# 241         241           NaN           NaN         NaN         NaN
# 242         242       October        2024.0         May      2025.0
#
#     clientSpaceSize spaceCleaniness waitingSpace examinationroomTemperature  \
# 0               NaN             NaN          NaN                        NaN
# 1               NaN             NaN          NaN                        NaN
# 2               NaN             NaN          NaN                        NaN
# 3               NaN             NaN          NaN                        NaN
# 4               NaN             NaN          NaN                        NaN
# ..              ...             ...          ...                        ...
# 238             NaN             NaN          NaN                        NaN
# 239             NaN             NaN          NaN                        NaN
# 240             NaN             NaN          NaN                        NaN
# 241             NaN             NaN          NaN                        NaN
# 242             NaN             NaN          NaN                        NaN
#
#     examionationroomLighting  ...  \
# 0                        NaN  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                        NaN  ...
# ..                       ...  ...
# 238                      NaN  ...
# 239                      NaN  ...
# 240                      NaN  ...
# 241                      NaN  ...
# 242                      NaN  ...
#
#     comments_and_recommendations_data_triangulation today  \
# 0                                               NaN   NaN
# 1                                               NaN   NaN
# 2                                               NaN   NaN
# 3                                               NaN   NaN
# 4                                               NaN   NaN
# ..                                              ...   ...
# 238                                             NaN   NaN
# 239                                             NaN   NaN
# 240                                             NaN   NaN
# 241                                             NaN   NaN
# 242                                             NaN   NaN
#
#     designation__job_title full_name organisation section     District  \
# 0                      NaN       NaN          NaN       b     HURUNGWE
# 1                      NaN       NaN          NaN       b     HURUNGWE
# 2                      NaN       NaN          NaN       b     HURUNGWE
# 3                      NaN       NaN          NaN       b  GOKWE SOUTH
# 4                      NaN       NaN          NaN       b      CHEGUTU
# ..                     ...       ...          ...     ...          ...
# 238                    NaN       NaN          NaN       d      SANYATI
# 239                    NaN       NaN          NaN       c    MARONDERA
# 240                    NaN       NaN          NaN       d    MARONDERA
# 241                    NaN       NaN          NaN       e    MARONDERA
# 242                    NaN       NaN          NaN       b    MARONDERA
#
#               facility                            month_year_repeat_group  \
# 0        Helwin Clinic  [{'calculatedMonth': 'April', 'calculatedYear'...
# 1    Karuru RDC Clinic  [{'calculatedMonth': 'April', 'calculatedYear'...
# 2       Moy RDC Clinic  [{'calculatedMonth': 'April', 'calculatedYear'...
# 3        Tongwe Clinic  [{'calculatedMonth': 'April', 'calculatedYear'...
# 4          Norton hosp                                               None
# ..                 ...                                                ...
# 238             Rimuka                                               None
# 239         Dombotombo                                               None
# 240         Dombotombo                                               None
# 241         Dombotombo                                               None
# 242         Dombotombo  [{'calculatedMonth': 'October', 'calculatedYea...
#
#         username
# 0       amutenha
# 1       amutenha
# 2       amutenha
# 3        gguveya
# 4          percy
# ..           ...
# 238      fgwenzi
# 239  tmunyaradzi
# 240     jgavhera
# 241     jgavhera
# 242     amutenha
#
# [243 rows x 627 columns]
